# %% [markdown]
# ### Set working directory

# %%
import os 
print("starting directory: ", os.getcwd())
os.chdir("/w/halld-scshelf2101/home/dbarton/gluex/analysis")
print("changed directory to: ", os.getcwd())
# Out:
# starting directory:  /w/halld-scshelf2101/home/dbarton/gluex/analysis
# changed directory to:  /w/halld-scshelf2101/home/dbarton/gluex/analysis

# %% [markdown]
# ### Create DataFrame, list branches

# %%
import ROOT
from ROOT import RDataFrame

fileName = '/work/halld/home/dbarton/gluex/dselectors/pi0kplamb_flat_2018_08.root'
treeName = 'pi0kplamb_flat'

def buildDataFrame(fileName, treeName):
    df = ROOT.RDataFrame(treeName, fileName)
    
    return df

dfpi0kplamb = buildDataFrame(fileName, treeName)

# List branches
def list_trees_and_branches(filename):
    file = ROOT.TFile.Open(filename)
    # Loop over all keys in the file
    for key in file.GetListOfKeys():
        obj = key.ReadObj()
        # Check if the object is a tree
        if isinstance(obj, ROOT.TTree):
            tree = obj
            print(f"File: {filename}")
            print(f"Tree: {tree.GetName()}")
            print("Branches:")
            # List all branches in the tree
            branches = tree.GetListOfBranches()
            for branch in branches:
                print(f" - {branch.GetName()}")

    # Close the file
    file.Close()
list_trees_and_branches(fileName)
# Out:
# File: /work/halld/home/dbarton/gluex/dselectors/pi0kplamb_flat_2018_08.root
# Tree: pi0kplamb_flat
# Branches:
#  - beam_e
#  - beam_e_measured
#  - kp_m
#  - kp_m_measured
#  - kp_m2
#  - kp_m2_measured
#  - decayingPi0_m
#  - decayingPi0_m2
#  - photon1_E
#  - photon1_E_measured
#  - photon1_p
#  - photon1_p_measured
#  - photon2_E
#  - photon2_E_measured
#  - photon2_p
#  - photon2_p_measured
#  - decayingLambda_m
#  - decayingLambda_m_measured
#  - decayingLambda_m2
#  - decayingLambda_m2_measured
#  - decayingLambda_E
#  - decayingLambda_E_measured
#  - pim_m
#  - pim_m_measured
#  - pim_m2
#  - pim_m2_measured
#  - protonRecoil_m
#  - protonRecoil_m_measured
#  - protonRecoil_m2
#  - protonRecoil_m2_measured
#  - kpANDPi0_m
#  - kpANDPi0_E
#  - kpANDphoton1_E
#  - kpANDphoton1_E_measured
#  - kpANDphoton2_E
#  - kpANDphoton2_E_measured
#  - kpANDlambda_m
#  - kpANDlambda_m_measured
#  - kpANDlambda_E
#  - kpANDproton_m
#  - kpANDproton_m_measured
#  - kpANDpim_m
#  - kpANDpim_m_measured
#  - pi0ANDlambda_m
#  - pi0ANDproton_m
#  - pi0ANDpim_m
#  - dEdx_cdc_kplus
#  - dEdx_fdc_kplus
#  - t
#  - t0
#  - tPrime
#  - s

# %% [markdown]
# ### Define cuts

# %% [markdown]
# <p style="text-align: center;">
# <u style="font-size:12px;">_____________</u><br>
# <u style="font-size:18px;">_____________________</u><br>
# <u style="font-size:24px;">___________________________</u>
# </p>
#
# <h2 style="text-align: center;">PLOTS</h2>
#
# <p style="text-align: center;">
# <u style="font-size:24px;">___________________________</u><br>
# <u style="font-size:18px;">_____________________</u><br>
# <u style="font-size:12px;">_____________</u>
# </p>

# %% [markdown]
# ### Beam Energy

# %%
from IPython.display import Image, display

def plot_hist(df):

    dfFiltered = df

    canvas = ROOT.TCanvas("c", "c", 800, 600)
    h1 = dfFiltered.Histo1D(("h1", "Beam energy", 60, 4, 13), 'beam_e')
    # h1.SetState(False)
    h1.SetLineColor(ROOT.kBlue)
    h1.SetTitle("Beam energy")
    h1.GetXaxis().SetTitle("Beam energy [GeV]")
    h1.GetYaxis().SetTitle("Events")
    h1.Draw()

    img_path = '../_plots/pi0kplamb_beam_e.png'
    canvas.SaveAs(img_path)
    canvas.Close()
    display(Image(filename=img_path))

plot_hist(dfpi0kplamb)
# Out:
# Info in <TCanvas::Print>: png file ../_plots/pi0kplamb_beam_e.png has been created

# %% [markdown]
# ### Target proton

# %%
from IPython.display import Image, display

def plot_hist(df):

    dfFiltered = df

    canvas = ROOT.TCanvas("c", "c", 800, 600)
    h1 = dfFiltered.Histo1D(("h1", "Target Proton mass", 60, 0, 3), '??????')
    # h1.SetState(False)
    h1.SetLineColor(ROOT.kBlue)
    h1.GetXaxis().SetTitle('P (GeV/c^{2})')
    h1.GetYaxis().SetTitle('Events')
    h1.Draw()

    img_path = '../_plots/pi0kplamb_target_m.png'
    canvas.SaveAs(img_path)
    canvas.Close()
    display(Image(filename=img_path))

plot_hist(dfpi0kplamb)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 20
#      17     canvas.Close()
#      18     display(Image(filename=img_path))
# ---> 20 plot_hist(dfpi0kplamb)
#
# Cell In[62], line 8, in plot_hist(df)
#       5 dfFiltered = df
#       7 canvas = ROOT.TCanvas("c", "c", 800, 600)
# ----> 8 h1 = dfFiltered.Histo1D(("h1", "Target Proton mass", 60, 0, 3), '??????')
#       9 # h1.SetState(False)
#      10 h1.SetLineColor(ROOT.kBlue)
#
# File /group/halld/Software/builds/Linux_Alma9-x86_64-gcc11.4.1/root/root-6.24.04/lib/ROOT/pythonization/_rdataframe.py:120, in _histo_profile(self, fixed_args, *args)
#     117 # Call the original implementation of the method
#     118 # with the model as first argument
#     119 if len(args) > 1:
# --> 120     res = original_method(model, *args[1:])
#     121 else:
#     122     # Covers the case of the overloads with only model passed
#     123     # as argument
#     124     res = original_method(model)
#
# TypeError: Template method resolution failed:
#   none of the 4 overloaded methods succeeded. Full details:
#   ROOT::RDF::RResultPtr<TH1D> ROOT::RDF::RInterface<ROOT::Detail::RDF::RLoopManager,void>::Histo1D(experimental::basic_string_view<char,char_traits<char> > vName) =>
#     TypeError: takes at most 1 arguments (2 given)
#   ROOT::RDF::RResultPtr<TH1D> ROOT::RDF::RInterface<ROOT::Detail::RDF::RLoopManager,void>::Histo1D(const ROOT::RDF::TH1DModel& model, experimental::basic_string_view<char,char_traits<char> > vName, experimental::basic_string_view<char,char_traits<char> > wName) =>
#     TypeError: takes at least 3 arguments (2 given)
#   ROOT::RDF::RResultPtr<TH1D> ROOT::RDF::RInterface<ROOT::Detail::RDF::RLoopManager,void>::Histo1D(experimental::basic_string_view<char,char_traits<char> > vName, experimental::basic_string_view<char,char_traits<char> > wName) =>
#     TypeError: could not convert argument 1
#   ROOT::RDF::RResultPtr<TH1D> ROOT::RDF::RInterface<ROOT::Detail::RDF::RLoopManager,void>::Histo1D(const ROOT::RDF::TH1DModel& model = {"", "", 128U, 0., 0.}, experimental::basic_string_view<char,char_traits<char> > vName = "") =>
#     runtime_error: Unknown column: ??????
#   none of the 4 overloaded methods succeeded. Full details:
#   ROOT::RDF::RResultPtr<TH1D> ROOT::RDF::RInterface<ROOT::Detail::RDF::RLoopManager,void>::Histo1D(experimental::basic_string_view<char,char_traits<char> > vName) =>
#     TypeError: takes at most 1 arguments (2 given)
#   ROOT::RDF::RResultPtr<TH1D> ROOT::RDF::RInterface<ROOT::Detail::RDF::RLoopManager,void>::Histo1D(const ROOT::RDF::TH1DModel& model, experimental::basic_string_view<char,char_traits<char> > vName, experimental::basic_string_view<char,char_traits<char> > wName) =>
#     TypeError: takes at least 3 arguments (2 given)
#   ROOT::RDF::RResultPtr<TH1D> ROOT::RDF::RInterface<ROOT::Detail::RDF::RLoopManager,void>::Histo1D(experimental::basic_string_view<char,char_traits<char> > vName, experimental::basic_string_view<char,char_traits<char> > wName) =>
#     TypeError: could not convert argument 1
#   ROOT::RDF::RResultPtr<TH1D> ROOT::RDF::RInterface<ROOT::Detail::RDF::RLoopManager,void>::Histo1D(const ROOT::RDF::TH1DModel& model = {"", "", 128U, 0., 0.}, experimental::basic_string_view<char,char_traits<char> > vName = "") =>
#     runtime_error: Unknown column: ??????
#   Failed to instantiate "Histo1D(ROOT::RDF::TH1DModel*,std::string)"
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %% [markdown]
# ### $K^{+}$ mass

# %%
from IPython.display import Image, display

def plot_hist(df):

    dfFiltered = df

    canvas = ROOT.TCanvas('c', 'c', 800, 600)
    h1 = dfFiltered.Histo1D(('h1', 'K^{+} Mass', 60, 0.45, 0.55), 'kp_m')
    # h1.SetState(False)
    h1.SetLineColor(ROOT.kBlue)
    h1.GetXaxis().SetTitle('K^{+} (GeV/c^{2})')
    h1.GetYaxis().SetTitle('Events')
    h1.Draw()

    img_path = '../_plots/pi0kplamb_kp_m.png'
    canvas.SaveAs(img_path)
    canvas.Close()
    display(Image(filename=img_path))

plot_hist(dfpi0kplamb)
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ../_plots/pi0kplamb_kp_m.png has been created

# %% [markdown]
# ### $\pi_{0}$ mass

# %%
from IPython.display import Image, display

def plot_hist(df):

    dfFiltered = df

    canvas = ROOT.TCanvas('c', 'c', 800, 600)
    h1 = dfFiltered.Histo1D(('h1', '$\pi^{0}$ Mass', 60, 0.05, 0.2), 'decayingPi0_m')
    # h1.SetState(False)
    h1.SetLineColor(ROOT.kBlue)
    h1.GetXaxis().SetTitle('$\pi^{0}$ (GeV/c^{2})')
    h1.GetYaxis().SetTitle('Events')
    h1.Draw()

    img_path = '../_plots/pi0kplamb_pi0_m.png'
    canvas.SaveAs(img_path)
    canvas.Close()
    display(Image(filename=img_path))

plot_hist(dfpi0kplamb)
# Out:
# Info in <TCanvas::Print>: png file ../_plots/pi0kplamb_pi0_m.png has been created

# %% [markdown]
# ### $\Lambda$ mass

# %%
from IPython.display import Image, display

def plot_hist(df):

    dfFiltered = df

    canvas = ROOT.TCanvas('c', 'c', 800, 600)
    h1 = dfFiltered.Histo1D(('h1', '$\Lambda$ Mass', 60, 1.0, 2.0), 'decayingLambda_m')
    # h1.SetState(False)
    h1.SetLineColor(ROOT.kBlue)
    h1.GetXaxis().SetTitle('$\Lambda$ (GeV/c^{2})')
    h1.GetYaxis().SetTitle('Events')
    h1.Draw()

    img_path = '../_plots/pi0kplamb_lambda_m.png'
    canvas.SaveAs(img_path)
    canvas.Close()
    display(Image(filename=img_path))

plot_hist(dfpi0kplamb)
# Out:
# Info in <TCanvas::Print>: png file ../_plots/pi0kplamb_lambda_m.png has been created

# %% [markdown]
# ### $\gamma_{1}$ energy

# %%
from IPython.display import Image, display

def plot_hist(df):

    dfFiltered = df

    canvas = ROOT.TCanvas('c', 'c', 800, 600)
    h1 = dfFiltered.Histo1D(('h1', '$\gamma_{1}$ Energy', 60, 0.005, 6.0), 'photon1_E')
    # h1.SetState(False)
    h1.SetLineColor(ROOT.kBlue)
    h1.GetXaxis().SetTitle('$\gamma_{1}$ (GeV)')
    h1.GetYaxis().SetTitle('Events')
    h1.Draw()

    img_path = '../_plots/pi0kplamb_photon1_E.png'
    canvas.SaveAs(img_path)
    canvas.Close()
    display(Image(filename=img_path))

plot_hist(dfpi0kplamb)
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file ../_plots/pi0kplamb_photon1_E.png has been created

# %% [markdown]
# ### $\gamma_{2}$ energy

# %%
from IPython.display import Image, display

def plot_hist(df):

    dfFiltered = df

    canvas = ROOT.TCanvas('c', 'c', 800, 600)
    h1 = dfFiltered.Histo1D(('h1', '$\gamma_{1}$ Energy', 60, 0.005, 6.0), 'photon2_E')
    # h1.SetState(False)
    h1.SetLineColor(ROOT.kBlue)
    h1.GetXaxis().SetTitle('$\gamma_{2}$ (GeV)')
    h1.GetYaxis().SetTitle('Events')
    h1.Draw()

    img_path = '../_plots/pi0kplamb_photon2_E.png'
    canvas.SaveAs(img_path)
    canvas.Close()
    display(Image(filename=img_path))

plot_hist(dfpi0kplamb)
# Out:
# Info in <TCanvas::Print>: png file ../_plots/pi0kplamb_photon2_E.png has been created

# %% [markdown]
# ### Recoiling proton energy

# %%
from IPython.display import Image, display

def plot_hist(df):

    dfFiltered = df

    canvas = ROOT.TCanvas('c', 'c', 800, 600)
    h1 = dfFiltered.Histo1D(('h1', 'Proton mass', 60, 0.9, 1.0), 'protonRecoil_m')
    # h1.SetState(False)
    h1.SetLineColor(ROOT.kBlue)
    h1.GetXaxis().SetTitle('Recoil proton (GeV/c^{2})')
    h1.GetYaxis().SetTitle('Events')
    h1.Draw()

    img_path = '../_plots/pi0kplamb_protonRecoil_m.png'
    canvas.SaveAs(img_path)
    canvas.Close()
    display(Image(filename=img_path))

plot_hist(dfpi0kplamb)
# Out:
# Info in <TCanvas::Print>: png file ../_plots/pi0kplamb_protonRecoil_m.png has been created

# %% [markdown]
# ### $\pi_{-}$ mass

# %%
from IPython.display import Image, display

def plot_hist(df):

    dfFiltered = df

    canvas = ROOT.TCanvas('c', 'c', 800, 600)
    h1 = dfFiltered.Histo1D(('h1', '$\gamma_{1}$ Energy', 60, 0.1, 0.18), 'pim_m')
    # h1.SetState(False)
    h1.SetLineColor(ROOT.kBlue)
    h1.GetXaxis().SetTitle('$\gamma_{1}$ (GeV)')
    h1.GetYaxis().SetTitle('Events')
    h1.Draw()

    img_path = '../_plots/pi0kplamb_pim_m.png'
    canvas.SaveAs(img_path)
    canvas.Close()
    display(Image(filename=img_path))

plot_hist(dfpi0kplamb)
# Out:
# Info in <TCanvas::Print>: png file ../_plots/pi0kplamb_pim_m.png has been created
